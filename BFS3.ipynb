# %%
from lib.TaxiEnv import TaxiEnv
import numpy as np
from time import time
from lib.utilities import getInverseAction,renderStates
env = TaxiEnv()
env.print = False

# %%
def bfs (env, startState):
    errStates = []
    #for k in range(env.allStatesCount):
    statesTisTurn = []
    statesNextTurn = []

    statesTisTurn.append(startState)
    states = {}
    genericMaskLen = len(env.getLastActionMask())
    gotResult = False
    goThrough = False
    onBoard = False
    done = False

    finalPath = []
    #For every pre-fetched actions
    while not gotResult:
        #print(statesTisTurn)
        #print("")

        while len(statesTisTurn) > 0:
        
            i = statesTisTurn.pop(0)
            #print(i,end=",")
            state, actionMask = env.setState(i, True)
            if not (state in states):
                states[state] = [False,[]]
            # For each action:
            for actionId in range(genericMaskLen):        
                #If action is not viable skip
                if(actionMask[actionId]) == 0:
                    continue
                #Else :
                #Set the previous state:
                env.setState(i)
                #Make a move
                nxtState, rew, done ,_,_ = env.move(actionId)
                #If the action was "pickup" - start from here next itteration
                if(actionId == 4):
                    statesTisTurn = []
                    statesNextTurn = []
                    onBoard = True
                    #statesNextTurn = [nxtState]
                #If I am done - return with the path
                if(done):
                    finalPath = states[state].copy()
                    finalPath[1].append(nxtState)
                    gotResult = True
                    break
                #If we have the passenger onboard but the action doesn't make it "done" - end
                elif(actionId == 5):
                    continue
                #If next state hasn't been checked - add an empty array
                if not (nxtState in states):
                    states[nxtState] = [False,[]]
                    goThrough = True
                #If the nextState hasn't been searched or shorter path has been found
                if goThrough or onBoard != states[nxtState][0]  or (len(states[nxtState][1]) > len(states[state][1])+1 ) :
                    goThrough = False
                    #print(rew)
                    states[nxtState][1] = states[state][1].copy()
                    states[nxtState][1].append(state)
                    states[nxtState][0] = onBoard
                    statesNextTurn.append(nxtState)
                #else:
                    #print("Not updated - " + str(nxtState) + " from state " + str(state))
        else:
            #print("yes")
            #break
            statesTisTurn = statesNextTurn.copy()
            #print(statesNextTurn)
            statesNextTurn = []
    return finalPath

# %%
# env.setState(137)
# env.printCurState()

# %%
from time import sleep
for i in range(500):
    env = TaxiEnv()
    env.print = False
    renderStates(bfs(env,i)[1])
    sleep(2)
# Out:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/sipekd/Desktop/ReinforcementLearning/BFS3.ipynb Cell 4 line 5
#       <a href='vscode-notebook-cell:/home/sipekd/Desktop/ReinforcementLearning/BFS3.ipynb#X11sZmlsZQ%3D%3D?line=2'>3</a> env = TaxiEnv()
#       <a href='vscode-notebook-cell:/home/sipekd/Desktop/ReinforcementLearning/BFS3.ipynb#X11sZmlsZQ%3D%3D?line=3'>4</a> env.print = False
# ----> <a href='vscode-notebook-cell:/home/sipekd/Desktop/ReinforcementLearning/BFS3.ipynb#X11sZmlsZQ%3D%3D?line=4'>5</a> renderStates(bfs(env,i)[1])
#       <a href='vscode-notebook-cell:/home/sipekd/Desktop/ReinforcementLearning/BFS3.ipynb#X11sZmlsZQ%3D%3D?line=5'>6</a> sleep(2)
#
# File ~/Desktop/ReinforcementLearning/lib/utilities.py:23, in renderStates(stateList, animSpeed)
#      21 clear_output()
#      22 env.printCurState()
# ---> 23 sleep(animSpeed)
#
# KeyboardInterrupt:

# %%
errStates
# Out:
# [1,
#  2,
#  3,
#  4,
#  7,
#  8,
#  9,
#  11,
#  12,
#  13,
#  17,
#  18,
#  19,
#  21,
#  22,
#  23,
#  24,
#  27,
#  28,
#  29,
#  31,
#  32,
#  33,
#  37,
#  39,
#  41,
#  42,
#  43,
#  44,
#  47,
#  48,
#  49,
#  51,
#  52,
#  53,
#  56,
#  59,
#  61,
#  62,
#  63,
#  64,
#  67,
#  68,
#  69,
#  71,
#  72,
#  73,
#  76,
#  77,
#  79,
#  81,
#  82,
#  83,
#  84,
#  87,
#  88,
#  89,
#  91,
#  92,
#  93,
#  96,
#  99,
#  101,
#  102,
#  103,
#  104,
#  107,
#  108,
#  109,
#  111,
#  112,
#  113,
#  116,
#  117,
#  118,
#  119,
#  121,
#  122,
#  123,
#  124,
#  127,
#  128,
#  129,
#  131,
#  132,
#  133,
#  137,
#  139,
#  141,
#  142,
#  143,
#  144,
#  147,
#  148,
#  149,
#  151,
#  152,
#  153,
#  156,
#  159,
#  161,
#  162,
#  163,
#  164,
#  167,
#  168,
#  169,
#  171,
#  172,
#  173,
#  176,
#  177,
#  179,
#  181,
#  182,
#  183,
#  184,
#  187,
#  188,
#  189,
#  191,
#  192,
#  193,
#  196,
#  197,
#  199,
#  201,
#  202,
#  203,
#  204,
#  207,
#  208,
#  209,
#  211,
#  212,
#  213,
#  216,
#  217,
#  218,
#  219,
#  221,
#  222,
#  223,
#  224,
#  227,
#  228,
#  229,
#  231,
#  232,
#  233,
#  236,
#  237,
#  239,
#  241,
#  242,
#  243,
#  244,
#  247,
#  248,
#  249,
#  251,
#  252,
#  253,
#  256,
#  257,
#  259,
#  261,
#  262,
#  263,
#  264,
#  267,
#  268,
#  269,
#  271,
#  272,
#  273,
#  276,
#  277,
#  279,
#  281,
#  282,
#  283,
#  284,
#  287,
#  288,
#  289,
#  291,
#  292,
#  293,
#  296,
#  297,
#  299,
#  301,
#  302,
#  303,
#  304,
#  307,
#  308,
#  309,
#  311,
#  312,
#  313,
#  316,
#  317,
#  318,
#  319,
#  321,
#  322,
#  323,
#  324,
#  327,
#  328,
#  329,
#  331,
#  332,
#  333,
#  336,
#  337,
#  339,
#  341,
#  342,
#  343,
#  344,
#  347,
#  348,
#  349,
#  351,
#  352,
#  353,
#  356,
#  357,
#  359,
#  361,
#  362,
#  363,
#  364,
#  367,
#  368,
#  369,
#  371,
#  372,
#  373,
#  376,
#  377,
#  379,
#  381,
#  382,
#  383,
#  384,
#  387,
#  388,
#  389,
#  391,
#  392,
#  393,
#  396,
#  397,
#  399,
#  401,
#  402,
#  403,
#  404,
#  407,
#  408,
#  409,
#  411,
#  412,
#  413,
#  416,
#  417,
#  419,
#  421,
#  422,
#  423,
#  424,
#  427,
#  428,
#  429,
#  431,
#  432,
#  433,
#  436,
#  437,
#  439,
#  441,
#  442,
#  443,
#  444,
#  447,
#  448,
#  449,
#  451,
#  452,
#  453,
#  456,
#  457,
#  459,
#  461,
#  462,
#  463,
#  464,
#  467,
#  468,
#  469,
#  471,
#  472,
#  473,
#  476,
#  477,
#  481,
#  482,
#  483,
#  484,
#  487,
#  488,
#  489,
#  491,
#  492,
#  493,
#  496,
#  497]
